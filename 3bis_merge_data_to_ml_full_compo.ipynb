# %%
import pandas as pd

import mysql.connector

from sqlalchemy import create_engine

from skimpy import skim

from datetime import datetime

# %% [markdown]
# # 0- importation des données en df

# %%
username = 'postgres'
password = 'admin'
host = '127.0.0.1'  # ou l'adresse IP de votre serveur PostgreSQL
port = '5432'  # le port par défaut pour PostgreSQL est 5432
database = 'preventive_maintenance'

# Créer l'URL de connexion
db_url = f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}'

# Créer le moteur SQLAlchemy
engine = create_engine(db_url)

# Se connecter à la base de données
connexion = engine.connect()

# %%
df_aero = pd.read_sql_query('''
                  SELECT * 
                  FROM aeronefs
                  ''', connexion)

# %%
df_composants = pd.read_sql_query('''
                  SELECT * 
                  FROM composants
                  ''', connexion)

# %%
df_degradations = pd.read_sql_query('''
                  SELECT * 
                  FROM degradations
                  ''', connexion)

# %%
df_logs_vols = pd.read_sql_query('''
                  SELECT * 
                  FROM logs_vols
                  ''', connexion)

# %%
connexion.close()

# %% [markdown]
# # 1- merge des dataframes

# %%
# merge du degradations et composants en left join avec degradations en left

df_merge_deg_compo = pd.merge(df_degradations, df_composants, how='inner', left_on='compo_concerned', right_on='ref_compo')

# %%
df_merge_deg_compo.head(1)
# Out:
#                                                 clef  ref_deg  linked_aero  \
# 0  D001982CRJ700_6943SYSCRJ700-CRJ700_6943-292024...  D001982  CRJ700_6943
#
#             compo_concerned  usure_nouvelle measure_day  need_replacement  \
# 0  SYSCRJ700-CRJ700_6943-29       16.941998  2024-06-02             False
#
#                   ref_compo           categorie         aero  \
# 0  SYSCRJ700-CRJ700_6943-29  Composants Majeurs  CRJ700_6943
#
#                         desc_compo  lifespan  taux_usure_actuel   cout
# 0  Système d'extinction d'incendie     11971          16.941998  10109

# %%
# faire un group by par categoriee et ref_aero
df_merge_deg_compo_gb = df_merge_deg_compo.groupby(['aero', 'desc_compo', 'measure_day']).agg({'usure_nouvelle': ['max', 'mean']}).reset_index()

# Aplatir les colonnes
df_merge_deg_compo_gb.columns = ['_'.join(col).strip().replace(' ', '_') if col[1] else col[0] for col in df_merge_deg_compo_gb.columns.values]

# %%
# faire un pivot pour obtenir une seule ligne par avion
df_pivot = df_merge_deg_compo_gb.pivot_table(index=['aero', 'measure_day'], columns=['desc_compo'], values=['usure_nouvelle_max', 'usure_nouvelle_mean'], aggfunc='first').reset_index()

df_pivot.columns = ['_'.join([str(i) for i in col]).strip().replace(' ', '_')  for col in df_pivot.columns.values]

# %%
df_pivot['measure_day_'] = df_pivot['measure_day_'].astype('str')

# %%
# ajout d'une clé aero et mesure_day
df_pivot['cle'] = df_pivot.apply(lambda x: x['aero_'] + '_' + x['measure_day_'], axis=1)

# %%
df_logs_vols
# Out:
#         ref_vol aero_linked    jour_vol  time_en_air  \
# 0     V06783026   A320_6242  2024-06-04          6.2
# 1     V06810954   A380_5199  2024-06-04          2.1
# 2     V05201226   A350_3122  2024-06-04          7.7
# 3     V05582404   B747_3165  2024-06-04          8.3
# 4     V01713095   A350_6452  2024-06-04          9.8
# ...         ...         ...         ...          ...
# 5237  V08907808   A350_6495  2024-07-25          6.6
# 5238  V01846975   E175_5414  2024-07-25          2.7
# 5239  V09385402   E175_0620  2024-07-25          5.8
# 5240  V04742938   B747_1460  2024-07-25          3.7
# 5241  V03372489   A320_6924  2024-07-25          4.7
#
#                                             sensor_data  etat_voyant  temp  \
# 0     {'temp': '-14.7°C', 'pressure': '1009.1 hPa', ...            1 -14.7
# 1     {'temp': '2.9°C', 'pressure': '1015.8 hPa', 'v...            0   2.9
# 2     {'temp': '8.0°C', 'pressure': '934.2 hPa', 'vi...            0   8.0
# 3     {'temp': '7.3°C', 'pressure': '999.9 hPa', 'vi...            0   7.3
# 4     {'temp': '-11.4°C', 'pressure': '946.7 hPa', '...            0 -11.4
# ...                                                 ...          ...   ...
# 5237  {'temp': '13.8°C', 'pressure': '899.0 hPa', 'v...            0  13.8
# 5238  {'temp': '-24.2°C', 'pressure': '1051.4 hPa', ...            1 -24.2
# 5239  {'temp': '1.9°C', 'pressure': '907.5 hPa', 'vi...            0   1.9
# 5240  {'temp': '-20.2°C', 'pressure': '1074.7 hPa', ...            1 -20.2
# 5241  {'temp': '6.9°C', 'pressure': '1027.3 hPa', 'v...            0   6.9
#
#      temp_unit  pressure pressure_unit  vibrations vibrations_unit
# 0           °C    1009.1           hPa    0.015340            m/s²
# 1           °C    1015.8           hPa    2.317764            m/s²
# 2           °C     934.2           hPa    1.999378            m/s²
# 3           °C     999.9           hPa    0.875383            m/s²
# 4           °C     946.7           hPa    1.551531            m/s²
# ...        ...       ...           ...         ...             ...
# 5237        °C     899.0           hPa    1.876524            m/s²
# 5238        °C    1051.4           hPa    0.888896            m/s²
# 5239        °C     907.5           hPa    3.648072            m/s²
# 5240        °C    1074.7           hPa    2.406679            m/s²
# 5241        °C    1027.3           hPa    3.213598            m/s²
#
# [5242 rows x 12 columns]

# %%
df_logs_vols['jour_vol'] = df_logs_vols['jour_vol'].astype('str')

# %%
# ajout d'une clé aero et mesure_day sur le df_logs_vols
df_logs_vols['cle'] = df_logs_vols.apply(lambda x: x['aero_linked'] + '_' + x['jour_vol'], axis=1)

# %%
# merge de df_log_vol et df_pivot

df_merge_pivot_logvol = pd.merge(df_pivot, df_logs_vols, how='inner', left_on='cle', right_on='cle')

# %%
# merge de df_aero et df_merge_pivot_logvol

df_merge_tot = pd.merge(df_merge_pivot_logvol, df_aero, how='inner', left_on='aero_linked', right_on='ref_aero')

# %%
df_merge_tot.shape
# Out:
# (5216, 109)

# %%
del df_aero, df_logs_vols, df_merge_pivot_logvol, df_degradations, df_composants

# %% [markdown]
# # 2- Nettoayage du df

# %%
# df_merge_tot.columns

# %%
# suppression des colonne n'apportant pas d'informations
df_merge_tot = df_merge_tot.drop(columns=[
                            'cle', 'ref_vol',
                            'aero_linked', 'jour_vol', 'sensor_data', 
                            'temp_unit', 'pressure_unit',
                            'vibrations_unit', 'ref_aero', 
                            'end_maint'])

# %%
pd.set_option("display.max_columns", None)

# %%
# skim(df_merge_total)

# %%
# modification du type pour date 
df_merge_tot['debut_service'] = pd.to_datetime(df_merge_tot['debut_service'], format='%Y-%m-%d')
df_merge_tot['last_maint'] = pd.to_datetime(df_merge_tot['last_maint'], format='%Y-%m-%d')
df_merge_tot['measure_day'] = pd.to_datetime(df_merge_tot['measure_day_'], format='%Y-%m-%d')

# %%
# modif type category
df_merge_tot['etat_voyant'] = df_merge_tot['etat_voyant'].astype('category')

# %%
# Ajout d'une colonne temps de vol cumulé depuis la derniere maintenance

# Assumons que df_merge_total est le DataFrame fourni et qu'il contient les colonnes 'temps_de_vol', 'last_maint', 'jour_vol', et 'ref_aero'
# Trier le DataFrame par avion et par date de vol
df_merge_total_sort = df_merge_tot.sort_values(by=['aero_', 'measure_day']).reset_index(drop=True)

# Initialiser la colonne 'temps_de_vol_cumule' et 'etat_voyant_suivant' avec des zéros
df_merge_total_sort['temps_de_vol_cumule'] = 0
df_merge_total_sort['etat_voyant_suivant'] = 0

# Parcourir chaque avion
for avion in df_merge_total_sort['aero_'].unique():
    
    # Filtrer les données pour l'avion actuel
    df_avion = df_merge_total_sort[df_merge_total_sort['aero_'] == avion]
    
    # Variable pour stocker le temps de vol cumulé
    temps_de_vol_cumule = 0
    
    # Parcourir chaque ligne du DataFrame filtré pour l'avion actuel
    for i in df_avion.index:
      
        # Si la maintenance a eu lieu (en supposant que 'last_maint' est un booléen ou indicatif)
        if (i != 0 and ((df_merge_total_sort.loc[i, 'last_maint'].date() == df_merge_total_sort.loc[i, 'measure_day'].date()) or
            (df_merge_total_sort.loc[i-1, 'etat_voyant'] != 0))):
            # Réinitialiser le temps de vol cumulé
            temps_de_vol_cumule = 0
        
        # Ajouter le temps de vol actuel au temps de vol cumulé
        temps_de_vol_cumule += df_merge_total_sort.loc[i, 'time_en_air']
        
        # Mettre à jour la colonne 'temps_de_vol_cumule'
        df_merge_total_sort.loc[i, 'temps_de_vol_cumule'] = temps_de_vol_cumule

        if i < len(df_merge_total_sort)-1:
            df_merge_total_sort.loc[i,'etat_voyant_suivant'] = df_merge_total_sort.loc[i+1, 'etat_voyant']
# Out:
# C:\Users\dimle\AppData\Local\Temp\ipykernel_28196\525427120.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_merge_total_sort.loc[i, 'temps_de_vol_cumule'] = temps_de_vol_cumule

# %%
df_merge_total_sort.head(5)
# Out:
#        aero_ measure_day_  usure_nouvelle_max_Ailerons  \
# 0  A320_1884   2024-06-04                    24.424320
# 1  A320_1884   2024-06-05                    25.203096
# 2  A320_1884   2024-06-08                    25.466196
# 3  A320_1884   2024-06-10                    25.529340
# 4  A320_1884   2024-06-14                    25.908204
#
#    usure_nouvelle_max_Autopilote  usure_nouvelle_max_Détecteurs_de_fumée  \
# 0                      30.542460                                6.841880
# 1                      31.641138                                7.660764
# 2                      32.012313                                7.937414
# 3                      32.101395                                8.003810
# 4                      32.635887                                8.402186
#
#    usure_nouvelle_max_Empennage  usure_nouvelle_max_Flaps  \
# 0                     36.802480                 17.114500
# 1                     37.818944                 17.930350
# 2                     38.162344                 18.205975
# 3                     38.244760                 18.272125
# 4                     38.739256                 18.669025
#
#    usure_nouvelle_max_Freins  usure_nouvelle_max_Gouvernail_de_direction  \
# 0                  17.502700                                   40.335740
# 1                  18.317810                                   41.271322
# 2                  18.593185                                   41.587397
# 3                  18.659275                                   41.663255
# 4                  19.055815                                   42.118403
#
#    usure_nouvelle_max_Générateur_électrique  usure_nouvelle_max_Hublots  \
# 0                                 30.028880                   28.256040
# 1                                 31.043864                   33.360412
# 2                                 31.386764                   35.084862
# 3                                 31.469060                   35.498730
# 4                                 31.962836                   37.981938
#
#    usure_nouvelle_max_Ordinateur_de_vol  usure_nouvelle_max_Porte_cargo  \
# 0                             36.529380                       28.500460
# 1                             37.302014                       29.347538
# 2                             37.563039                       29.633713
# 3                             37.625685                       29.702395
# 4                             38.001561                       30.114487
#
#    usure_nouvelle_max_Portes_passagers  \
# 0                            26.189260
# 1                            27.159178
# 2                            27.486853
# 3                            27.565495
# 4                            28.037347
#
#    usure_nouvelle_max_Radar_météorologique  usure_nouvelle_max_Réacteur_droit  \
# 0                                35.666140                          43.442680
# 1                                36.548442                          44.451004
# 2                                36.846517                          44.791654
# 3                                36.918055                          44.873410
# 4                                37.347283                          45.363946
#
#    usure_nouvelle_max_Réacteur_gauche  usure_nouvelle_max_Siège_copilote  \
# 0                           12.128100                            45.7960
# 1                           13.093430                            46.8468
# 2                           13.419555                            47.2018
# 3                           13.497825                            47.2870
# 4                           13.967445                            47.7982
#
#    usure_nouvelle_max_Siège_pilote  usure_nouvelle_max_Spoilers  \
# 0                        54.049080                    28.316680
# 1                        54.944924                    29.310204
# 2                        55.247574                    29.645854
# 3                        55.320210                    29.726410
# 4                        55.756026                    30.209746
#
#    usure_nouvelle_max_Système_anti-givre  \
# 0                               8.395260
# 1                               9.490978
# 2                               9.861153
# 3                               9.949995
# 4                              10.483047
#
#    usure_nouvelle_max_Système_d'alerte_de_proximité_au_sol_(GPWS)  \
# 0                                           9.426140
# 1                                          10.197442
# 2                                          10.458017
# 3                                          10.520555
# 4                                          10.895783
#
#    usure_nouvelle_max_Système_d'annonce_publique  \
# 0                                      29.247680
# 1                                      30.274504
# 2                                      30.621404
# 3                                      30.704660
# 4                                      31.204196
#
#    usure_nouvelle_max_Système_d'approvisionnement_en_eau  \
# 0                                          38.843280
# 1                                          39.790184
# 2                                          40.110084
# 3                                          40.186860
# 4                                          40.647516
#
#    usure_nouvelle_max_Système_d'atterrissage_automatique  \
# 0                                          61.126660
# 1                                          62.128398
# 2                                          62.466823
# 3                                          62.548045
# 4                                          63.035377
#
#    usure_nouvelle_max_Système_d'extinction_d'incendie  \
# 0                                          10.674780
# 1                                          11.560634
# 2                                          11.859909
# 3                                          11.931735
# 4                                          12.362691
#
#    usure_nouvelle_max_Système_de_commande_des_gaz  \
# 0                                       48.834460
# 1                                       49.703738
# 2                                       49.997413
# 3                                       50.067895
# 4                                       50.490787
#
#    usure_nouvelle_max_Système_de_communication_radio  \
# 0                                           23.01660
# 1                                           23.78398
# 2                                           24.04323
# 3                                           24.10545
# 4                                           24.47877
#
#    usure_nouvelle_max_Système_de_conditionnement_d'air  \
# 0                                          60.781740
# 1                                          61.547122
# 2                                          61.805697
# 3                                          61.867755
# 4                                          62.240103
#
#    usure_nouvelle_max_Système_de_contrôle_de_vol  \
# 0                                       14.73440
# 1                                       15.66532
# 2                                       15.97982
# 3                                       16.05530
# 4                                       16.50818
#
#    usure_nouvelle_max_Système_de_contrôle_des_surfaces_de_vol  \
# 0                                          59.582500
# 1                                          60.405750
# 2                                          60.683875
# 3                                          60.750625
# 4                                          61.151125
#
#    usure_nouvelle_max_Système_de_divertissement_en_vol  \
# 0                                          26.367300
# 1                                          27.402190
# 2                                          27.751815
# 3                                          27.835725
# 4                                          28.339185
#
#    usure_nouvelle_max_Système_de_gestion_de_carburant  \
# 0                                          25.969420
# 1                                          26.947626
# 2                                          27.278101
# 3                                          27.357415
# 4                                          27.833299
#
#    usure_nouvelle_max_Système_de_gestion_électrique  \
# 0                                         27.943620
# 1                                         28.713886
# 2                                         28.974111
# 3                                         29.036565
# 4                                         29.411289
#
#    usure_nouvelle_max_Système_de_navigation  \
# 0                                 15.487380
# 1                                 16.267414
# 2                                 16.530939
# 3                                 16.594185
# 4                                 16.973661
#
#    usure_nouvelle_max_Système_de_pressurisation  \
# 0                                     45.950840
# 1                                     46.789852
# 2                                     47.073302
# 3                                     47.141330
# 4                                     47.549498
#
#    usure_nouvelle_max_Système_de_surveillance_du_trafic_aérien  \
# 0                                          23.064140
# 1                                          23.805842
# 2                                          24.056417
# 3                                          24.116555
# 4                                          24.477383
#
#    usure_nouvelle_max_Système_hydraulique_principal  \
# 0                                         19.635980
# 1                                         20.731994
# 2                                         21.102269
# 3                                         21.191135
# 4                                         21.724331
#
#    usure_nouvelle_max_Systèmes_d'oxygène_d'urgence  \
# 0                                        23.216840
# 1                                        24.181652
# 2                                        24.507602
# 3                                        24.585830
# 4                                        25.055198
#
#    usure_nouvelle_max_Toilettes  \
# 0                      19.24140
# 1                      20.22042
# 2                      20.55117
# 3                      20.63055
# 4                      21.10683
#
#    usure_nouvelle_max_Train_d'atterrissage_avant  \
# 0                                      43.963520
# 1                                      44.996856
# 2                                      45.345956
# 3                                      45.429740
# 4                                      45.932444
#
#    usure_nouvelle_max_Train_d'atterrissage_principal  \
# 0                                          47.520020
# 1                                          48.288806
# 2                                          48.548531
# 3                                          48.610865
# 4                                          48.984869
#
#    usure_nouvelle_max_Unité_de_gestion_de_l'air  \
# 0                                     14.450320
# 1                                     15.428896
# 2                                     15.759496
# 3                                     15.838840
# 4                                     16.314904
#
#    usure_nouvelle_max_Éclairage_d'urgence  \
# 0                               59.684620
# 1                               60.747186
# 2                               61.106161
# 3                               61.192315
# 4                               61.709239
#
#    usure_nouvelle_max_Éclairage_de_cabine  \
# 0                                3.960220
# 1                                4.905866
# 2                                5.225341
# 3                                5.302015
# 4                                5.762059
#
#    usure_nouvelle_max_Éclairage_de_la_cabine  usure_nouvelle_mean_Ailerons  \
# 0                                  18.205020                     24.424320
# 1                                  18.992306                     25.203096
# 2                                  19.258281                     25.466196
# 3                                  19.322115                     25.529340
# 4                                  19.705119                     25.908204
#
#    usure_nouvelle_mean_Autopilote  usure_nouvelle_mean_Détecteurs_de_fumée  \
# 0                       30.542460                                 6.841880
# 1                       31.641138                                 7.660764
# 2                       32.012313                                 7.937414
# 3                       32.101395                                 8.003810
# 4                       32.635887                                 8.402186
#
#    usure_nouvelle_mean_Empennage  usure_nouvelle_mean_Flaps  \
# 0                      36.802480                  17.114500
# 1                      37.818944                  17.930350
# 2                      38.162344                  18.205975
# 3                      38.244760                  18.272125
# 4                      38.739256                  18.669025
#
#    usure_nouvelle_mean_Freins  usure_nouvelle_mean_Gouvernail_de_direction  \
# 0                   17.502700                                    40.335740
# 1                   18.317810                                    41.271322
# 2                   18.593185                                    41.587397
# 3                   18.659275                                    41.663255
# 4                   19.055815                                    42.118403
#
#    usure_nouvelle_mean_Générateur_électrique  usure_nouvelle_mean_Hublots  \
# 0                                  30.028880                    28.256040
# 1                                  31.043864                    33.360412
# 2                                  31.386764                    35.084862
# 3                                  31.469060                    35.498730
# 4                                  31.962836                    37.981938
#
#    usure_nouvelle_mean_Ordinateur_de_vol  usure_nouvelle_mean_Porte_cargo  \
# 0                              36.529380                        28.500460
# 1                              37.302014                        29.347538
# 2                              37.563039                        29.633713
# 3                              37.625685                        29.702395
# 4                              38.001561                        30.114487
#
#    usure_nouvelle_mean_Portes_passagers  \
# 0                             26.189260
# 1                             27.159178
# 2                             27.486853
# 3                             27.565495
# 4                             28.037347
#
#    usure_nouvelle_mean_Radar_météorologique  \
# 0                                 35.666140
# 1                                 36.548442
# 2                                 36.846517
# 3                                 36.918055
# 4                                 37.347283
#
#    usure_nouvelle_mean_Réacteur_droit  usure_nouvelle_mean_Réacteur_gauche  \
# 0                           43.442680                            12.128100
# 1                           44.451004                            13.093430
# 2                           44.791654                            13.419555
# 3                           44.873410                            13.497825
# 4                           45.363946                            13.967445
#
#    usure_nouvelle_mean_Siège_copilote  usure_nouvelle_mean_Siège_pilote  \
# 0                             45.7960                         54.049080
# 1                             46.8468                         54.944924
# 2                             47.2018                         55.247574
# 3                             47.2870                         55.320210
# 4                             47.7982                         55.756026
#
#    usure_nouvelle_mean_Spoilers  usure_nouvelle_mean_Système_anti-givre  \
# 0                     28.316680                                8.395260
# 1                     29.310204                                9.490978
# 2                     29.645854                                9.861153
# 3                     29.726410                                9.949995
# 4                     30.209746                               10.483047
#
#    usure_nouvelle_mean_Système_d'alerte_de_proximité_au_sol_(GPWS)  \
# 0                                           9.426140
# 1                                          10.197442
# 2                                          10.458017
# 3                                          10.520555
# 4                                          10.895783
#
#    usure_nouvelle_mean_Système_d'annonce_publique  \
# 0                                       29.247680
# 1                                       30.274504
# 2                                       30.621404
# 3                                       30.704660
# 4                                       31.204196
#
#    usure_nouvelle_mean_Système_d'approvisionnement_en_eau  \
# 0                                          38.843280
# 1                                          39.790184
# 2                                          40.110084
# 3                                          40.186860
# 4                                          40.647516
#
#    usure_nouvelle_mean_Système_d'atterrissage_automatique  \
# 0                                          61.126660
# 1                                          62.128398
# 2                                          62.466823
# 3                                          62.548045
# 4                                          63.035377
#
#    usure_nouvelle_mean_Système_d'extinction_d'incendie  \
# 0                                          10.674780
# 1                                          11.560634
# 2                                          11.859909
# 3                                          11.931735
# 4                                          12.362691
#
#    usure_nouvelle_mean_Système_de_commande_des_gaz  \
# 0                                        48.834460
# 1                                        49.703738
# 2                                        49.997413
# 3                                        50.067895
# 4                                        50.490787
#
#    usure_nouvelle_mean_Système_de_communication_radio  \
# 0                                           23.01660
# 1                                           23.78398
# 2                                           24.04323
# 3                                           24.10545
# 4                                           24.47877
#
#    usure_nouvelle_mean_Système_de_conditionnement_d'air  \
# 0                                          47.246740
# 1                                          48.012122
# 2                                          48.270697
# 3                                          48.332755
# 4                                          48.705103
#
#    usure_nouvelle_mean_Système_de_contrôle_de_vol  \
# 0                                        14.73440
# 1                                        15.66532
# 2                                        15.97982
# 3                                        16.05530
# 4                                        16.50818
#
#    usure_nouvelle_mean_Système_de_contrôle_des_surfaces_de_vol  \
# 0                                          59.582500
# 1                                          60.405750
# 2                                          60.683875
# 3                                          60.750625
# 4                                          61.151125
#
#    usure_nouvelle_mean_Système_de_divertissement_en_vol  \
# 0                                          26.367300
# 1                                          27.402190
# 2                                          27.751815
# 3                                          27.835725
# 4                                          28.339185
#
#    usure_nouvelle_mean_Système_de_gestion_de_carburant  \
# 0                                          25.969420
# 1                                          26.947626
# 2                                          27.278101
# 3                                          27.357415
# 4                                          27.833299
#
#    usure_nouvelle_mean_Système_de_gestion_électrique  \
# 0                                          27.943620
# 1                                          28.713886
# 2                                          28.974111
# 3                                          29.036565
# 4                                          29.411289
#
#    usure_nouvelle_mean_Système_de_navigation  \
# 0                                  15.487380
# 1                                  16.267414
# 2                                  16.530939
# 3                                  16.594185
# 4                                  16.973661
#
#    usure_nouvelle_mean_Système_de_pressurisation  \
# 0                                      45.950840
# 1                                      46.789852
# 2                                      47.073302
# 3                                      47.141330
# 4                                      47.549498
#
#    usure_nouvelle_mean_Système_de_surveillance_du_trafic_aérien  \
# 0                                          23.064140
# 1                                          23.805842
# 2                                          24.056417
# 3                                          24.116555
# 4                                          24.477383
#
#    usure_nouvelle_mean_Système_hydraulique_principal  \
# 0                                          19.635980
# 1                                          20.731994
# 2                                          21.102269
# 3                                          21.191135
# 4                                          21.724331
#
#    usure_nouvelle_mean_Systèmes_d'oxygène_d'urgence  \
# 0                                         23.216840
# 1                                         24.181652
# 2                                         24.507602
# 3                                         24.585830
# 4                                         25.055198
#
#    usure_nouvelle_mean_Toilettes  \
# 0                       19.24140
# 1                       20.22042
# 2                       20.55117
# 3                       20.63055
# 4                       21.10683
#
#    usure_nouvelle_mean_Train_d'atterrissage_avant  \
# 0                                       43.963520
# 1                                       44.996856
# 2                                       45.345956
# 3                                       45.429740
# 4                                       45.932444
#
#    usure_nouvelle_mean_Train_d'atterrissage_principal  \
# 0                                          47.520020
# 1                                          48.288806
# 2                                          48.548531
# 3                                          48.610865
# 4                                          48.984869
#
#    usure_nouvelle_mean_Unité_de_gestion_de_l'air  \
# 0                                      14.450320
# 1                                      15.428896
# 2                                      15.759496
# 3                                      15.838840
# 4                                      16.314904
#
#    usure_nouvelle_mean_Éclairage_d'urgence  \
# 0                                59.684620
# 1                                60.747186
# 2                                61.106161
# 3                                61.192315
# 4                                61.709239
#
#    usure_nouvelle_mean_Éclairage_de_cabine  \
# 0                                 3.960220
# 1                                 4.905866
# 2                                 5.225341
# 3                                 5.302015
# 4                                 5.762059
#
#    usure_nouvelle_mean_Éclairage_de_la_cabine  time_en_air etat_voyant  temp  \
# 0                                   18.205020          9.8           0   4.3
# 1                                   18.992306          7.4           1 -24.3
# 2                                   19.258281          2.5           0  -8.4
# 3                                   19.322115          0.6           0  17.4
# 4                                   19.705119          3.6           0  18.3
#
#    pressure  vibrations type_model debut_service last_maint  en_maintenance  \
# 0     907.3    1.763677       A320    2015-12-26 2024-06-01           False
# 1     905.9    3.428686       A320    2015-12-26 2024-06-01           False
# 2     962.5    1.290613       A320    2015-12-26 2024-06-01           False
# 3     872.1    3.525162       A320    2015-12-26 2024-06-01           False
# 4     986.5    0.973155       A320    2015-12-26 2024-06-01           False
#
#   measure_day  temps_de_vol_cumule  etat_voyant_suivant
# 0  2024-06-04                  9.8                    1
# 1  2024-06-05                 17.2                    0
# 2  2024-06-08                  2.5                    0
# 3  2024-06-10                  3.1                    0
# 4  2024-06-14                  6.7                    0

# %%
# skim(df_merge_total)

# %%
df_merge_total_sort.to_parquet('data_preclean_avion_full_compo.parquet')
