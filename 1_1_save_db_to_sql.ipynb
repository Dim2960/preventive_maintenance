# %%
import pandas as pd
from sqlalchemy import create_engine,  MetaData, Table
from datetime import date
import datetime

import json
import re

# %% [markdown]
# ## Ouverture des csv en dataframe

# %% [markdown]
# ### aeronefs

# %%
# ouvrir csv pour mettre en data frame
df_aeronef = pd.read_csv(r'dataset\aeronefs_clean.csv')

# %%
df_aeronef
# Out:
#         ref_aero type_model debut_service  last_maint  en_maintenance  \
# 0      E170_6356       E170    2000-03-17  2024-03-27           False
# 1      B767_2803       B767    2020-12-03  2024-06-01           False
# 2    CRJ700_6943     CRJ700    2015-01-29  2024-06-02            True
# 3      A350_1177       A350    2005-08-07  2024-01-04           False
# 4      B777_4029       B777    2009-01-01  2024-06-01           False
# ..           ...        ...           ...         ...             ...
# 226    B737_4369       B737    2010-01-05  2024-06-01           False
# 227    A340_4021       A340    2004-12-13  2024-05-31           False
# 228  CRJ900_1740     CRJ900    2003-07-20  2024-06-01           False
# 229    E170_5551       E170    2021-04-10  2024-06-01           False
# 230  CRJ700_2988     CRJ700    2000-10-25  2024-02-01           False
#
#                end_maint
# 0                    NaN
# 1                    NaN
# 2    2024-06-03 14:13:00
# 3                    NaN
# 4                    NaN
# ..                   ...
# 226                  NaN
# 227                  NaN
# 228                  NaN
# 229                  NaN
# 230                  NaN
#
# [231 rows x 6 columns]

# %%
# convertir les données avant insertion dans la table sql
df_aeronef['debut_service'] = pd.to_datetime(df_aeronef['debut_service'])
df_aeronef['last_maint'] = pd.to_datetime(df_aeronef['last_maint'])
df_aeronef['end_maint'] = pd.to_datetime(df_aeronef['end_maint'])

df_aeronef['en_maintenance'] = df_aeronef['en_maintenance'].astype('boolean')

# %%
df_aeronef
# Out:
#         ref_aero type_model debut_service last_maint  en_maintenance  \
# 0      E170_6356       E170    2000-03-17 2024-03-27           False
# 1      B767_2803       B767    2020-12-03 2024-06-01           False
# 2    CRJ700_6943     CRJ700    2015-01-29 2024-06-02            True
# 3      A350_1177       A350    2005-08-07 2024-01-04           False
# 4      B777_4029       B777    2009-01-01 2024-06-01           False
# ..           ...        ...           ...        ...             ...
# 226    B737_4369       B737    2010-01-05 2024-06-01           False
# 227    A340_4021       A340    2004-12-13 2024-05-31           False
# 228  CRJ900_1740     CRJ900    2003-07-20 2024-06-01           False
# 229    E170_5551       E170    2021-04-10 2024-06-01           False
# 230  CRJ700_2988     CRJ700    2000-10-25 2024-02-01           False
#
#               end_maint
# 0                   NaT
# 1                   NaT
# 2   2024-06-03 14:13:00
# 3                   NaT
# 4                   NaT
# ..                  ...
# 226                 NaT
# 227                 NaT
# 228                 NaT
# 229                 NaT
# 230                 NaT
#
# [231 rows x 6 columns]

# %% [markdown]
# ### Composants

# %%
# ouvrir csv pour mettre en data frame
df_composants = pd.read_csv(r'dataset\composants_clean.csv')

# %%
# convertir les données avant insertion dans la table sql

# -> pas de besoin

# %%
df_composants.head()
# Out:
#              ref_compo             categorie       aero  \
# 0  REAE170-E170_6353-0  Composants Critiques  E170_6353
# 1  REAE170-E170_6353-1  Composants Critiques  E170_6353
# 2  SYSE170-E170_6353-2  Composants Critiques  E170_6353
# 3  ORDE170-E170_6353-3  Composants Critiques  E170_6353
# 4  AUTE170-E170_6353-4  Composants Critiques  E170_6353
#
#               desc_compo  lifespan  taux_usure_actuel   cout
# 0        Réacteur gauche     13045          53.308375  15552
# 1         Réacteur droit     13626          50.111950  17559
# 2  Système de navigation     10541          16.730575  16514
# 3      Ordinateur de vol     10441           6.653075  16047
# 4             Autopilote     14847          42.033525  19362

# %% [markdown]
# ### degradations

# %%
# cration date du jour
aujourdhui = date.today()
aujourdhui = aujourdhui.strftime('%Y-%m-%d')

# aujourdhui = '2024-07-23'

# %%
# ouvrir csv pour mettre en data frame
df_degradations = pd.read_csv(f'http://sc-e.fr/docs/degradations_{aujourdhui}.csv')

# %%
df_degradations.head()
# Out:
#    ref_deg linked_aero      compo_concerned  usure_nouvelle measure_day  \
# 0  D003661   E170_6353  REAE170-E170_6353-0       74.467365  2024-07-22
# 1  D009402   E170_6353  REAE170-E170_6353-1       72.213322  2024-07-22
# 2  D000812   E170_6353  SYSE170-E170_6353-2       33.828077  2024-07-22
# 3  D006665   E170_6353  ORDE170-E170_6353-3       23.588377  2024-07-22
# 4  D001163   E170_6353  AUTE170-E170_6353-4       66.115359  2024-07-22
#
#    need_replacement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# #### preparation des données / nettoyage

# %%
# Ajout d'une colonne pour primaryKey
df_degradations.insert(0, 'clef', df_degradations.apply(lambda row: str(row['ref_deg']) + str(row['linked_aero'])  + str(row['compo_concerned'])+ str(row['measure_day']), axis=1))

# %%
#modification du type de la colonne date

df_degradations['measure_day'] = df_degradations['measure_day'].str.split().str[0]
df_degradations['measure_day'] = pd.to_datetime(df_degradations['measure_day'], format='%Y-%m-%d')

# %% [markdown]
# ### logs_vols

# %%
# ouvrir csv pour mettre en data frame
df_logs_vols = pd.read_csv(f'http://sc-e.fr/docs/logs_vols_{aujourdhui}.csv')

# %%
#modification du type de la colonne date

df_logs_vols['jour_vol'] = df_logs_vols['jour_vol'].str.split().str[0]
df_logs_vols['jour_vol'] = pd.to_datetime(df_logs_vols['jour_vol'], format='%Y-%m-%d')

# %%
# séparation de la colonne sensor_data en plusieurs colonne
# 1- regarder les diffrent sensor 

list_sensor = list()

for elem in df_logs_vols['sensor_data']:

    elem = json.loads(elem.replace('\'', '"'))

    for key in elem.keys():
        if key not in list_sensor:
            list_sensor.append(key)

list_sensor = set(list_sensor)

list_sensor
# Out:
# {'pressure', 'temp', 'vibrations'}

# %%
# découpage des sensor en colonne en supprimant les unités de la colonne et ajoutant une col unité

#patternn de séparation des unités
pattern = r"([-+]?\d*\.?\d+)((°C)?( hPa)?( m/s²)?)"

for sensor in list_sensor:
    df_logs_vols[sensor] = df_logs_vols['sensor_data'].apply(lambda x: re.match(pattern, json.loads(x.replace('\'', '"')).get(sensor)).group(1))
    df_logs_vols[f'{sensor}_unit'] = df_logs_vols['sensor_data'].apply(lambda x: re.match(pattern, json.loads(x.replace('\'', '"')).get(sensor)).group(2))

# %%
# passage des variables des sensors en float

for sensor in list_sensor:
    df_logs_vols[sensor] = df_logs_vols[sensor].astype(float)

# %%
df_logs_vols.head()
# Out:
#      ref_vol aero_linked   jour_vol  time_en_air  \
# 0  V09194923   E170_0081 2024-07-23          6.6
# 1  V07241227   B747_6747 2024-07-23          6.6
# 2  V01443548   A321_5206 2024-07-23          4.3
# 3  V06352606   B747_4152 2024-07-23          5.1
# 4  V04714204   B747_0472 2024-07-23          7.3
#
#                                          sensor_data  etat_voyant  vibrations  \
# 0  {'temp': '-10.0°C', 'pressure': '932.0 hPa', '...            0    3.773418
# 1  {'temp': '1.1°C', 'pressure': '963.7 hPa', 'vi...            0    2.634974
# 2  {'temp': '-14.2°C', 'pressure': '969.5 hPa', '...            1    0.121416
# 3  {'temp': '12.7°C', 'pressure': '956.8 hPa', 'v...            0    1.909083
# 4  {'temp': '-3.7°C', 'pressure': '928.2 hPa', 'v...            0    0.809483
#
#   vibrations_unit  pressure pressure_unit  temp temp_unit
# 0            m/s²     932.0           hPa -10.0        °C
# 1            m/s²     963.7           hPa   1.1        °C
# 2            m/s²     969.5           hPa -14.2        °C
# 3            m/s²     956.8           hPa  12.7        °C
# 4            m/s²     928.2           hPa  -3.7        °C

# %% [markdown]
# ## Connexion et insertion des données dans la bdd

# %% [markdown]
# ### Connexion à la bdd

# %%
# DÃ©finition des paramÃ¨tres de connexion Ã  la base de donnÃ©es
username = 'postgres'
password = 'admin'
host = 'localhost'
port = '5432'
dbname = 'preventive_maintenance'

# Configuration de la connexion Ã  la base de donnÃ©es PostgreSQL
connection_str = f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{dbname}'
engine = create_engine(connection_str, echo = False)

# generation de l'obet bdd
metadata = MetaData()
metadata.reflect(bind=engine)

# %% [markdown]
# ### declaration des tables

# %%
aeronefs = Table(
    'aeronefs', metadata,
    )

composants = Table(
    'composants', metadata,
    )

degradations = Table(
    'degradations', metadata,
    )

logs_vols = Table(
    'logs_vols', metadata,
    )

aeronefs_cdc = Table(
    'aeronefs_cdc', metadata,
    )

composants_cdc = Table(
    'composants_cdc', metadata,
    )

degradations_cdc = Table(
    'degradations_cdc', metadata,
    )

logs_vols_cdc = Table(
    'logs_vols_cdc', metadata,
    )

metadata.create_all(engine)

# %% [markdown]
# ### insertion des données

# %%
def maj_table(df:pd.DataFrame, table : Table, table_cdc : Table)->None:  # , ref_temp: str, data_to:dict[str:str, str:Date, str:int]
    """
    InsÃ¨re ou met à jour les donnÃ©es d'une table SQL à partir d'un DataFrame Pandas.

    Pour chaque ligne du DataFrame, la fonction vÃ©rifie si la rÃ©fÃ©rence (ref_aero) existe déjà dans la table.
    Si la rÃ©fÃ©rence n'existe pas, la ligne est insÃ©rÃ©e. Si la rÃ©fÃ©rence existe et que les donnÃ©es sont diffÃ©rentes,
    la ligne est mise à jour.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame contenant les donnÃ©es à insÃ©rer ou mettre à jour dans la table.
    table : Table
        Objet Table de SQLAlchemy reprÃ©sentant la table dans laquelle les donnÃ©es seront insÃ©rÃ©es ou mises à jour.
    """   
    with engine.connect() as connection:
        
        comptage_insertion = 0
        comptage_update = 0

        # Parcour de l'ensemble des lignes du df à  inserer
        for row in df.itertuples(index=False):

            data_to = {}
            
            # Préparation des données à  inserer ou updater
            column_names = df.columns

            for index, col in zip(range(len(row)), column_names):

                if row[index]  is not pd.NaT:
                    data_to[col] = row[index]
                else : 
                    data_to[col] = None


            primary_key_columns = table.primary_key.columns.keys()
            
            # Récupération de la valeur de la colonne reference/primarykey
            # Verification si la clé existe dans le dataframe
            if primary_key_columns[0] in data_to:
                ref_temp = data_to[primary_key_columns[0]]
            else : 
                break

            # identification si la ref est déjà  prÃ©sente ou non dans la table 
            sel = table.select().where(table.c[primary_key_columns[0]] == ref_temp)
            result = connection.execute(sel)   
            row_in_table = result.fetchone()    

            # # identification si les infos sont dejà  existantes dans la table cdc 
            # sel = table_cdc.select().where(table_cdc.c[primary_key_columns[0]] == ref_temp)
            # result = connection.execute(sel)   
            # row_in_table = result.fetchone()   

            if row_in_table is None: 
                
                #insertion de la ligne dans la table
                connection.execute(table.insert().values(data_to))
                comptage_insertion += 1

            else:
                # mise au meme format de row et row_in_table pour les dates
                row1 = [i for i in row]
                row2 = [i for i in row_in_table]

                for i, elem in enumerate(row2):

                    if isinstance(elem, datetime.date) or elem is None:

                        row2[i] = pd.Timestamp(row2[i])

                # Ajout de la condition de doublon ou non
                if row1 != row2 and row1[0] == row2[0]:
                    # update de la ligne dans la table si non doublon
                    connection.execute(table.update().where(table.c[primary_key_columns[0]] == ref_temp).values(data_to))
                    # Information sur la mise à jour
                    print(f'Comparaison des données pour MàJ : \n{row1}\n{row2}\n')
                    
                    comptage_update += 1
                
            # Commit dans la table des insertions ou update 
            connection.commit()

        # Affichage des rÃ©sultats
        print(f'Nombre de lignes insérées : {comptage_insertion}')
        print(f'Nombre de lignes mises à jour : {comptage_update}')

# %%
# maj_table(df_aeronef, aeronefs, aeronefs_cdc)

# %%
# maj_table(df_composants, composants, composants_cdc)

# %%
maj_table(df_degradations, degradations, degradations_cdc)
# Out:
# Nombre de lignes insérées : 0
# Nombre de lignes mises à jour : 0

# %%
maj_table(df_logs_vols, logs_vols, logs_vols_cdc)
# Out:
# Comparaison des données pour MàJ :
# ['V09194923', 'E170_0081', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '-10.0°C', 'pressure': '932.0 hPa', 'vibrations': '3.773417758644968 m/s²'}", 0, 3.773417758644968, ' m/s²', 932.0, ' hPa', -10.0, '°C']
# ['V09194923', 'E170_0081', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '-10.0°C', 'pressure': '932.0 hPa', 'vibrations': '3.773417758644968 m/s²'}", 0, -10.0, '°C', 932.0, ' hPa', 3.773417758644968, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07241227', 'B747_6747', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '1.1°C', 'pressure': '963.7 hPa', 'vibrations': '2.634973793033369 m/s²'}", 0, 2.634973793033369, ' m/s²', 963.7, ' hPa', 1.1, '°C']
# ['V07241227', 'B747_6747', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '1.1°C', 'pressure': '963.7 hPa', 'vibrations': '2.634973793033369 m/s²'}", 0, 1.1, '°C', 963.7, ' hPa', 2.634973793033369, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01443548', 'A321_5206', Timestamp('2024-07-23 00:00:00'), 4.3, "{'temp': '-14.2°C', 'pressure': '969.5 hPa', 'vibrations': '0.12141632205113995 m/s²'}", 1, 0.12141632205113995, ' m/s²', 969.5, ' hPa', -14.2, '°C']
# ['V01443548', 'A321_5206', Timestamp('2024-07-23 00:00:00'), 4.3, "{'temp': '-14.2°C', 'pressure': '969.5 hPa', 'vibrations': '0.12141632205113995 m/s²'}", 1, -14.2, '°C', 969.5, ' hPa', 0.12141632205113995, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06352606', 'B747_4152', Timestamp('2024-07-23 00:00:00'), 5.1, "{'temp': '12.7°C', 'pressure': '956.8 hPa', 'vibrations': '1.909083101980971 m/s²'}", 0, 1.909083101980971, ' m/s²', 956.8, ' hPa', 12.7, '°C']
# ['V06352606', 'B747_4152', Timestamp('2024-07-23 00:00:00'), 5.1, "{'temp': '12.7°C', 'pressure': '956.8 hPa', 'vibrations': '1.909083101980971 m/s²'}", 0, 12.7, '°C', 956.8, ' hPa', 1.909083101980971, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04714204', 'B747_0472', Timestamp('2024-07-23 00:00:00'), 7.3, "{'temp': '-3.7°C', 'pressure': '928.2 hPa', 'vibrations': '0.8094830801697883 m/s²'}", 0, 0.8094830801697883, ' m/s²', 928.2, ' hPa', -3.7, '°C']
# ['V04714204', 'B747_0472', Timestamp('2024-07-23 00:00:00'), 7.3, "{'temp': '-3.7°C', 'pressure': '928.2 hPa', 'vibrations': '0.8094830801697883 m/s²'}", 0, -3.7, '°C', 928.2, ' hPa', 0.8094830801697883, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04183131', 'B767_0906', Timestamp('2024-07-23 00:00:00'), 4.9, "{'temp': '9.3°C', 'pressure': '1029.6 hPa', 'vibrations': '1.0200332841693256 m/s²'}", 2, 1.0200332841693256, ' m/s²', 1029.6, ' hPa', 9.3, '°C']
# ['V04183131', 'B767_0906', Timestamp('2024-07-23 00:00:00'), 4.9, "{'temp': '9.3°C', 'pressure': '1029.6 hPa', 'vibrations': '1.0200332841693256 m/s²'}", 2, 9.3, '°C', 1029.6, ' hPa', 1.0200332841693256, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09789428', 'E175_6879', Timestamp('2024-07-23 00:00:00'), 1.7, "{'temp': '-6.3°C', 'pressure': '893.3 hPa', 'vibrations': '4.324264377195158 m/s²'}", 0, 4.324264377195158, ' m/s²', 893.3, ' hPa', -6.3, '°C']
# ['V09789428', 'E175_6879', Timestamp('2024-07-23 00:00:00'), 1.7, "{'temp': '-6.3°C', 'pressure': '893.3 hPa', 'vibrations': '4.324264377195158 m/s²'}", 0, -6.3, '°C', 893.3, ' hPa', 4.324264377195158, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09713612', 'B767_0277', Timestamp('2024-07-23 00:00:00'), 7.1, "{'temp': '-1.4°C', 'pressure': '971.1 hPa', 'vibrations': '0.9009071148491798 m/s²'}", 0, 0.9009071148491798, ' m/s²', 971.1, ' hPa', -1.4, '°C']
# ['V09713612', 'B767_0277', Timestamp('2024-07-23 00:00:00'), 7.1, "{'temp': '-1.4°C', 'pressure': '971.1 hPa', 'vibrations': '0.9009071148491798 m/s²'}", 0, -1.4, '°C', 971.1, ' hPa', 0.9009071148491798, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03278454', 'A340_4662', Timestamp('2024-07-23 00:00:00'), 1.6, "{'temp': '-3.6°C', 'pressure': '962.6 hPa', 'vibrations': '2.775051239392867 m/s²'}", 0, 2.775051239392867, ' m/s²', 962.6, ' hPa', -3.6, '°C']
# ['V03278454', 'A340_4662', Timestamp('2024-07-23 00:00:00'), 1.6, "{'temp': '-3.6°C', 'pressure': '962.6 hPa', 'vibrations': '2.775051239392867 m/s²'}", 0, -3.6, '°C', 962.6, ' hPa', 2.775051239392867, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02111126', 'A330_1199', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '9.9°C', 'pressure': '968.0 hPa', 'vibrations': '1.4993792765160374 m/s²'}", 0, 1.4993792765160374, ' m/s²', 968.0, ' hPa', 9.9, '°C']
# ['V02111126', 'A330_1199', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '9.9°C', 'pressure': '968.0 hPa', 'vibrations': '1.4993792765160374 m/s²'}", 0, 9.9, '°C', 968.0, ' hPa', 1.4993792765160374, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09283942', 'CRJ900_3749', Timestamp('2024-07-23 00:00:00'), 6.0, "{'temp': '19.3°C', 'pressure': '850.1 hPa', 'vibrations': '2.0671113846071014 m/s²'}", 0, 2.0671113846071014, ' m/s²', 850.1, ' hPa', 19.3, '°C']
# ['V09283942', 'CRJ900_3749', Timestamp('2024-07-23 00:00:00'), 6.0, "{'temp': '19.3°C', 'pressure': '850.1 hPa', 'vibrations': '2.0671113846071014 m/s²'}", 0, 19.3, '°C', 850.1, ' hPa', 2.0671113846071014, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07112891', 'A320_4367', Timestamp('2024-07-23 00:00:00'), 1.9, "{'temp': '-5.1°C', 'pressure': '888.5 hPa', 'vibrations': '1.8581371797886566 m/s²'}", 0, 1.8581371797886566, ' m/s²', 888.5, ' hPa', -5.1, '°C']
# ['V07112891', 'A320_4367', Timestamp('2024-07-23 00:00:00'), 1.9, "{'temp': '-5.1°C', 'pressure': '888.5 hPa', 'vibrations': '1.8581371797886566 m/s²'}", 0, -5.1, '°C', 888.5, ' hPa', 1.8581371797886566, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01021768', 'E175_1426', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '1.4°C', 'pressure': '923.6 hPa', 'vibrations': '4.597745657973891 m/s²'}", 0, 4.597745657973891, ' m/s²', 923.6, ' hPa', 1.4, '°C']
# ['V01021768', 'E175_1426', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '1.4°C', 'pressure': '923.6 hPa', 'vibrations': '4.597745657973891 m/s²'}", 0, 1.4, '°C', 923.6, ' hPa', 4.597745657973891, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06591313', 'B737_0940', Timestamp('2024-07-23 00:00:00'), 3.6, "{'temp': '20.0°C', 'pressure': '1000.1 hPa', 'vibrations': '0.9081803667519756 m/s²'}", 0, 0.9081803667519756, ' m/s²', 1000.1, ' hPa', 20.0, '°C']
# ['V06591313', 'B737_0940', Timestamp('2024-07-23 00:00:00'), 3.6, "{'temp': '20.0°C', 'pressure': '1000.1 hPa', 'vibrations': '0.9081803667519756 m/s²'}", 0, 20.0, '°C', 1000.1, ' hPa', 0.9081803667519756, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07008060', 'B767_2417', Timestamp('2024-07-23 00:00:00'), 5.4, "{'temp': '-12.1°C', 'pressure': '922.3 hPa', 'vibrations': '0.020158550631452776 m/s²'}", 1, 0.020158550631452776, ' m/s²', 922.3, ' hPa', -12.1, '°C']
# ['V07008060', 'B767_2417', Timestamp('2024-07-23 00:00:00'), 5.4, "{'temp': '-12.1°C', 'pressure': '922.3 hPa', 'vibrations': '0.020158550631452776 m/s²'}", 1, -12.1, '°C', 922.3, ' hPa', 0.020158550631452776, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07042477', 'B747_5923', Timestamp('2024-07-23 00:00:00'), 6.9, "{'temp': '-15.1°C', 'pressure': '881.2 hPa', 'vibrations': '1.6094265676025126 m/s²'}", 1, 1.6094265676025126, ' m/s²', 881.2, ' hPa', -15.1, '°C']
# ['V07042477', 'B747_5923', Timestamp('2024-07-23 00:00:00'), 6.9, "{'temp': '-15.1°C', 'pressure': '881.2 hPa', 'vibrations': '1.6094265676025126 m/s²'}", 1, -15.1, '°C', 881.2, ' hPa', 1.6094265676025126, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06889265', 'B737_2975', Timestamp('2024-07-23 00:00:00'), 8.0, "{'temp': '-7.0°C', 'pressure': '898.2 hPa', 'vibrations': '1.5614526729624316 m/s²'}", 0, 1.5614526729624316, ' m/s²', 898.2, ' hPa', -7.0, '°C']
# ['V06889265', 'B737_2975', Timestamp('2024-07-23 00:00:00'), 8.0, "{'temp': '-7.0°C', 'pressure': '898.2 hPa', 'vibrations': '1.5614526729624316 m/s²'}", 0, -7.0, '°C', 898.2, ' hPa', 1.5614526729624316, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06716209', 'A330_3548', Timestamp('2024-07-23 00:00:00'), 5.1, "{'temp': '6.7°C', 'pressure': '953.1 hPa', 'vibrations': '1.578955090882188 m/s²'}", 0, 1.578955090882188, ' m/s²', 953.1, ' hPa', 6.7, '°C']
# ['V06716209', 'A330_3548', Timestamp('2024-07-23 00:00:00'), 5.1, "{'temp': '6.7°C', 'pressure': '953.1 hPa', 'vibrations': '1.578955090882188 m/s²'}", 0, 6.7, '°C', 953.1, ' hPa', 1.578955090882188, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V00697402', 'A330_0921', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '13.5°C', 'pressure': '915.8 hPa', 'vibrations': '0.7797027898610209 m/s²'}", 0, 0.7797027898610209, ' m/s²', 915.8, ' hPa', 13.5, '°C']
# ['V00697402', 'A330_0921', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '13.5°C', 'pressure': '915.8 hPa', 'vibrations': '0.7797027898610209 m/s²'}", 0, 13.5, '°C', 915.8, ' hPa', 0.7797027898610209, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03475055', 'A380_0594', Timestamp('2024-07-23 00:00:00'), 1.7, "{'temp': '4.8°C', 'pressure': '906.8 hPa', 'vibrations': '1.7126903849900192 m/s²'}", 0, 1.7126903849900192, ' m/s²', 906.8, ' hPa', 4.8, '°C']
# ['V03475055', 'A380_0594', Timestamp('2024-07-23 00:00:00'), 1.7, "{'temp': '4.8°C', 'pressure': '906.8 hPa', 'vibrations': '1.7126903849900192 m/s²'}", 0, 4.8, '°C', 906.8, ' hPa', 1.7126903849900192, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02504925', 'CRJ900_3374', Timestamp('2024-07-23 00:00:00'), 6.5, "{'temp': '4.0°C', 'pressure': '912.5 hPa', 'vibrations': '2.235012159064892 m/s²'}", 0, 2.235012159064892, ' m/s²', 912.5, ' hPa', 4.0, '°C']
# ['V02504925', 'CRJ900_3374', Timestamp('2024-07-23 00:00:00'), 6.5, "{'temp': '4.0°C', 'pressure': '912.5 hPa', 'vibrations': '2.235012159064892 m/s²'}", 0, 4.0, '°C', 912.5, ' hPa', 2.235012159064892, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09449702', 'E175_5586', Timestamp('2024-07-23 00:00:00'), 4.2, "{'temp': '0.9°C', 'pressure': '895.7 hPa', 'vibrations': '1.4602310391993722 m/s²'}", 0, 1.4602310391993722, ' m/s²', 895.7, ' hPa', 0.9, '°C']
# ['V09449702', 'E175_5586', Timestamp('2024-07-23 00:00:00'), 4.2, "{'temp': '0.9°C', 'pressure': '895.7 hPa', 'vibrations': '1.4602310391993722 m/s²'}", 0, 0.9, '°C', 895.7, ' hPa', 1.4602310391993722, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02044818', 'A380_0710', Timestamp('2024-07-23 00:00:00'), 2.1, "{'temp': '-1.8°C', 'pressure': '907.4 hPa', 'vibrations': '2.5866140644486553 m/s²'}", 0, 2.5866140644486553, ' m/s²', 907.4, ' hPa', -1.8, '°C']
# ['V02044818', 'A380_0710', Timestamp('2024-07-23 00:00:00'), 2.1, "{'temp': '-1.8°C', 'pressure': '907.4 hPa', 'vibrations': '2.5866140644486553 m/s²'}", 0, -1.8, '°C', 907.4, ' hPa', 2.5866140644486553, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06683585', 'A350_6902', Timestamp('2024-07-23 00:00:00'), 3.0, "{'temp': '-6.1°C', 'pressure': '992.0 hPa', 'vibrations': '2.350551196019213 m/s²'}", 0, 2.350551196019213, ' m/s²', 992.0, ' hPa', -6.1, '°C']
# ['V06683585', 'A350_6902', Timestamp('2024-07-23 00:00:00'), 3.0, "{'temp': '-6.1°C', 'pressure': '992.0 hPa', 'vibrations': '2.350551196019213 m/s²'}", 0, -6.1, '°C', 992.0, ' hPa', 2.350551196019213, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07818470', 'B737_5581', Timestamp('2024-07-23 00:00:00'), 3.3, "{'temp': '-5.1°C', 'pressure': '824.7 hPa', 'vibrations': '0.8277954455714392 m/s²'}", 0, 0.8277954455714392, ' m/s²', 824.7, ' hPa', -5.1, '°C']
# ['V07818470', 'B737_5581', Timestamp('2024-07-23 00:00:00'), 3.3, "{'temp': '-5.1°C', 'pressure': '824.7 hPa', 'vibrations': '0.8277954455714392 m/s²'}", 0, -5.1, '°C', 824.7, ' hPa', 0.8277954455714392, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05736112', 'B747_3165', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '-9.1°C', 'pressure': '912.2 hPa', 'vibrations': '4.2452769597080104 m/s²'}", 0, 4.2452769597080104, ' m/s²', 912.2, ' hPa', -9.1, '°C']
# ['V05736112', 'B747_3165', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '-9.1°C', 'pressure': '912.2 hPa', 'vibrations': '4.2452769597080104 m/s²'}", 0, -9.1, '°C', 912.2, ' hPa', 4.2452769597080104, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01518683', 'B777_3944', Timestamp('2024-07-23 00:00:00'), 3.4, "{'temp': '0.8°C', 'pressure': '983.1 hPa', 'vibrations': '2.227982334897546 m/s²'}", 0, 2.227982334897546, ' m/s²', 983.1, ' hPa', 0.8, '°C']
# ['V01518683', 'B777_3944', Timestamp('2024-07-23 00:00:00'), 3.4, "{'temp': '0.8°C', 'pressure': '983.1 hPa', 'vibrations': '2.227982334897546 m/s²'}", 0, 0.8, '°C', 983.1, ' hPa', 2.227982334897546, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V00712157', 'A321_5105', Timestamp('2024-07-23 00:00:00'), 6.4, "{'temp': '7.7°C', 'pressure': '984.7 hPa', 'vibrations': '2.9601094690679424 m/s²'}", 0, 2.9601094690679424, ' m/s²', 984.7, ' hPa', 7.7, '°C']
# ['V00712157', 'A321_5105', Timestamp('2024-07-23 00:00:00'), 6.4, "{'temp': '7.7°C', 'pressure': '984.7 hPa', 'vibrations': '2.9601094690679424 m/s²'}", 0, 7.7, '°C', 984.7, ' hPa', 2.9601094690679424, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03546437', 'A380_0178', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '-3.5°C', 'pressure': '963.3 hPa', 'vibrations': '1.9110188236312347 m/s²'}", 0, 1.9110188236312347, ' m/s²', 963.3, ' hPa', -3.5, '°C']
# ['V03546437', 'A380_0178', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '-3.5°C', 'pressure': '963.3 hPa', 'vibrations': '1.9110188236312347 m/s²'}", 0, -3.5, '°C', 963.3, ' hPa', 1.9110188236312347, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09066489', 'B757_2518', Timestamp('2024-07-23 00:00:00'), 6.8, "{'temp': '-6.9°C', 'pressure': '919.2 hPa', 'vibrations': '0.5164051745726406 m/s²'}", 0, 0.5164051745726406, ' m/s²', 919.2, ' hPa', -6.9, '°C']
# ['V09066489', 'B757_2518', Timestamp('2024-07-23 00:00:00'), 6.8, "{'temp': '-6.9°C', 'pressure': '919.2 hPa', 'vibrations': '0.5164051745726406 m/s²'}", 0, -6.9, '°C', 919.2, ' hPa', 0.5164051745726406, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07234648', 'E170_3927', Timestamp('2024-07-23 00:00:00'), 1.3, "{'temp': '2.5°C', 'pressure': '981.7 hPa', 'vibrations': '3.5786061976288437 m/s²'}", 0, 3.5786061976288437, ' m/s²', 981.7, ' hPa', 2.5, '°C']
# ['V07234648', 'E170_3927', Timestamp('2024-07-23 00:00:00'), 1.3, "{'temp': '2.5°C', 'pressure': '981.7 hPa', 'vibrations': '3.5786061976288437 m/s²'}", 0, 2.5, '°C', 981.7, ' hPa', 3.5786061976288437, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05214827', 'CRJ700_1002', Timestamp('2024-07-23 00:00:00'), 5.2, "{'temp': '-2.8°C', 'pressure': '981.1 hPa', 'vibrations': '4.832019139669551 m/s²'}", 0, 4.832019139669551, ' m/s²', 981.1, ' hPa', -2.8, '°C']
# ['V05214827', 'CRJ700_1002', Timestamp('2024-07-23 00:00:00'), 5.2, "{'temp': '-2.8°C', 'pressure': '981.1 hPa', 'vibrations': '4.832019139669551 m/s²'}", 0, -2.8, '°C', 981.1, ' hPa', 4.832019139669551, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02797482', 'A330_3411', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '11.0°C', 'pressure': '986.7 hPa', 'vibrations': '3.463369898261356 m/s²'}", 0, 3.463369898261356, ' m/s²', 986.7, ' hPa', 11.0, '°C']
# ['V02797482', 'A330_3411', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '11.0°C', 'pressure': '986.7 hPa', 'vibrations': '3.463369898261356 m/s²'}", 0, 11.0, '°C', 986.7, ' hPa', 3.463369898261356, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01698764', 'E175_3843', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '4.6°C', 'pressure': '987.7 hPa', 'vibrations': '0.7585662633200996 m/s²'}", 0, 0.7585662633200996, ' m/s²', 987.7, ' hPa', 4.6, '°C']
# ['V01698764', 'E175_3843', Timestamp('2024-07-23 00:00:00'), 2.4, "{'temp': '4.6°C', 'pressure': '987.7 hPa', 'vibrations': '0.7585662633200996 m/s²'}", 0, 4.6, '°C', 987.7, ' hPa', 0.7585662633200996, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08046284', 'A350_3122', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '-0.6°C', 'pressure': '888.6 hPa', 'vibrations': '3.8318548052183425 m/s²'}", 0, 3.8318548052183425, ' m/s²', 888.6, ' hPa', -0.6, '°C']
# ['V08046284', 'A350_3122', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '-0.6°C', 'pressure': '888.6 hPa', 'vibrations': '3.8318548052183425 m/s²'}", 0, -0.6, '°C', 888.6, ' hPa', 3.8318548052183425, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02256577', 'B747_6800', Timestamp('2024-07-23 00:00:00'), 5.7, "{'temp': '-6.4°C', 'pressure': '1000.4 hPa', 'vibrations': '3.5947220352398066 m/s²'}", 2, 3.5947220352398066, ' m/s²', 1000.4, ' hPa', -6.4, '°C']
# ['V02256577', 'B747_6800', Timestamp('2024-07-23 00:00:00'), 5.7, "{'temp': '-6.4°C', 'pressure': '1000.4 hPa', 'vibrations': '3.5947220352398066 m/s²'}", 2, -6.4, '°C', 1000.4, ' hPa', 3.5947220352398066, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08250443', 'A350_6495', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '-2.9°C', 'pressure': '982.9 hPa', 'vibrations': '2.224067166873086 m/s²'}", 0, 2.224067166873086, ' m/s²', 982.9, ' hPa', -2.9, '°C']
# ['V08250443', 'A350_6495', Timestamp('2024-07-23 00:00:00'), 6.6, "{'temp': '-2.9°C', 'pressure': '982.9 hPa', 'vibrations': '2.224067166873086 m/s²'}", 0, -2.9, '°C', 982.9, ' hPa', 2.224067166873086, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03389346', 'B767_4965', Timestamp('2024-07-23 00:00:00'), 8.3, "{'temp': '18.6°C', 'pressure': '918.4 hPa', 'vibrations': '1.8491990263204254 m/s²'}", 0, 1.8491990263204254, ' m/s²', 918.4, ' hPa', 18.6, '°C']
# ['V03389346', 'B767_4965', Timestamp('2024-07-23 00:00:00'), 8.3, "{'temp': '18.6°C', 'pressure': '918.4 hPa', 'vibrations': '1.8491990263204254 m/s²'}", 0, 18.6, '°C', 918.4, ' hPa', 1.8491990263204254, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05389308', 'B767_2368', Timestamp('2024-07-23 00:00:00'), 7.4, "{'temp': '-13.4°C', 'pressure': '962.2 hPa', 'vibrations': '1.661653107057694 m/s²'}", 1, 1.661653107057694, ' m/s²', 962.2, ' hPa', -13.4, '°C']
# ['V05389308', 'B767_2368', Timestamp('2024-07-23 00:00:00'), 7.4, "{'temp': '-13.4°C', 'pressure': '962.2 hPa', 'vibrations': '1.661653107057694 m/s²'}", 1, -13.4, '°C', 962.2, ' hPa', 1.661653107057694, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08960125', 'A340_3614', Timestamp('2024-07-23 00:00:00'), 3.1, "{'temp': '-0.2°C', 'pressure': '958.1 hPa', 'vibrations': '2.3247924174236383 m/s²'}", 0, 2.3247924174236383, ' m/s²', 958.1, ' hPa', -0.2, '°C']
# ['V08960125', 'A340_3614', Timestamp('2024-07-23 00:00:00'), 3.1, "{'temp': '-0.2°C', 'pressure': '958.1 hPa', 'vibrations': '2.3247924174236383 m/s²'}", 0, -0.2, '°C', 958.1, ' hPa', 2.3247924174236383, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08311257', 'A340_4021', Timestamp('2024-07-23 00:00:00'), 4.3, "{'temp': '20.2°C', 'pressure': '921.5 hPa', 'vibrations': '2.489031729214986 m/s²'}", 1, 2.489031729214986, ' m/s²', 921.5, ' hPa', 20.2, '°C']
# ['V08311257', 'A340_4021', Timestamp('2024-07-23 00:00:00'), 4.3, "{'temp': '20.2°C', 'pressure': '921.5 hPa', 'vibrations': '2.489031729214986 m/s²'}", 1, 20.2, '°C', 921.5, ' hPa', 2.489031729214986, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05839959', 'B737_4369', Timestamp('2024-07-23 00:00:00'), 1.0, "{'temp': '-0.7°C', 'pressure': '946.2 hPa', 'vibrations': '4.853829312024351 m/s²'}", 0, 4.853829312024351, ' m/s²', 946.2, ' hPa', -0.7, '°C']
# ['V05839959', 'B737_4369', Timestamp('2024-07-23 00:00:00'), 1.0, "{'temp': '-0.7°C', 'pressure': '946.2 hPa', 'vibrations': '4.853829312024351 m/s²'}", 0, -0.7, '°C', 946.2, ' hPa', 4.853829312024351, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03928125', 'A320_5229', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '2.6°C', 'pressure': '964.8 hPa', 'vibrations': '2.591824604206072 m/s²'}", 0, 2.591824604206072, ' m/s²', 964.8, ' hPa', 2.6, '°C']
# ['V03928125', 'A320_5229', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '2.6°C', 'pressure': '964.8 hPa', 'vibrations': '2.591824604206072 m/s²'}", 0, 2.6, '°C', 964.8, ' hPa', 2.591824604206072, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09337485', 'A330_6095', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '8.6°C', 'pressure': '974.3 hPa', 'vibrations': '2.628722983871801 m/s²'}", 0, 2.628722983871801, ' m/s²', 974.3, ' hPa', 8.6, '°C']
# ['V09337485', 'A330_6095', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '8.6°C', 'pressure': '974.3 hPa', 'vibrations': '2.628722983871801 m/s²'}", 0, 8.6, '°C', 974.3, ' hPa', 2.628722983871801, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08832761', 'E175_2805', Timestamp('2024-07-23 00:00:00'), 9.8, "{'temp': '-10.7°C', 'pressure': '989.2 hPa', 'vibrations': '2.826559389429826 m/s²'}", 0, 2.826559389429826, ' m/s²', 989.2, ' hPa', -10.7, '°C']
# ['V08832761', 'E175_2805', Timestamp('2024-07-23 00:00:00'), 9.8, "{'temp': '-10.7°C', 'pressure': '989.2 hPa', 'vibrations': '2.826559389429826 m/s²'}", 0, -10.7, '°C', 989.2, ' hPa', 2.826559389429826, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04860738', 'B777_3000', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '0.6°C', 'pressure': '944.8 hPa', 'vibrations': '3.5304922892714803 m/s²'}", 0, 3.5304922892714803, ' m/s²', 944.8, ' hPa', 0.6, '°C']
# ['V04860738', 'B777_3000', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '0.6°C', 'pressure': '944.8 hPa', 'vibrations': '3.5304922892714803 m/s²'}", 0, 0.6, '°C', 944.8, ' hPa', 3.5304922892714803, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07131719', 'B737_3924', Timestamp('2024-07-23 00:00:00'), 9.2, "{'temp': '-11.3°C', 'pressure': '1011.3 hPa', 'vibrations': '0.9977445669901547 m/s²'}", 0, 0.9977445669901547, ' m/s²', 1011.3, ' hPa', -11.3, '°C']
# ['V07131719', 'B737_3924', Timestamp('2024-07-23 00:00:00'), 9.2, "{'temp': '-11.3°C', 'pressure': '1011.3 hPa', 'vibrations': '0.9977445669901547 m/s²'}", 0, -11.3, '°C', 1011.3, ' hPa', 0.9977445669901547, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05634459', 'B757_6477', Timestamp('2024-07-23 00:00:00'), 1.9, "{'temp': '-9.7°C', 'pressure': '949.5 hPa', 'vibrations': '0.7177504303564752 m/s²'}", 0, 0.7177504303564752, ' m/s²', 949.5, ' hPa', -9.7, '°C']
# ['V05634459', 'B757_6477', Timestamp('2024-07-23 00:00:00'), 1.9, "{'temp': '-9.7°C', 'pressure': '949.5 hPa', 'vibrations': '0.7177504303564752 m/s²'}", 0, -9.7, '°C', 949.5, ' hPa', 0.7177504303564752, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06239425', 'A350_1689', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '10.9°C', 'pressure': '1024.4 hPa', 'vibrations': '4.637732122508033 m/s²'}", 0, 4.637732122508033, ' m/s²', 1024.4, ' hPa', 10.9, '°C']
# ['V06239425', 'A350_1689', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '10.9°C', 'pressure': '1024.4 hPa', 'vibrations': '4.637732122508033 m/s²'}", 0, 10.9, '°C', 1024.4, ' hPa', 4.637732122508033, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07660287', 'B747_4211', Timestamp('2024-07-23 00:00:00'), 6.5, "{'temp': '-7.4°C', 'pressure': '928.2 hPa', 'vibrations': '1.7270955829066543 m/s²'}", 0, 1.7270955829066543, ' m/s²', 928.2, ' hPa', -7.4, '°C']
# ['V07660287', 'B747_4211', Timestamp('2024-07-23 00:00:00'), 6.5, "{'temp': '-7.4°C', 'pressure': '928.2 hPa', 'vibrations': '1.7270955829066543 m/s²'}", 0, -7.4, '°C', 928.2, ' hPa', 1.7270955829066543, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04870703', 'CRJ700_1788', Timestamp('2024-07-23 00:00:00'), 6.2, "{'temp': '4.0°C', 'pressure': '910.3 hPa', 'vibrations': '0.9467059824077467 m/s²'}", 0, 0.9467059824077467, ' m/s²', 910.3, ' hPa', 4.0, '°C']
# ['V04870703', 'CRJ700_1788', Timestamp('2024-07-23 00:00:00'), 6.2, "{'temp': '4.0°C', 'pressure': '910.3 hPa', 'vibrations': '0.9467059824077467 m/s²'}", 0, 4.0, '°C', 910.3, ' hPa', 0.9467059824077467, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09941491', 'B757_0375', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '21.8°C', 'pressure': '995.8 hPa', 'vibrations': '0.6169858754468155 m/s²'}", 1, 0.6169858754468155, ' m/s²', 995.8, ' hPa', 21.8, '°C']
# ['V09941491', 'B757_0375', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '21.8°C', 'pressure': '995.8 hPa', 'vibrations': '0.6169858754468155 m/s²'}", 1, 21.8, '°C', 995.8, ' hPa', 0.6169858754468155, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05478176', 'A321_1458', Timestamp('2024-07-23 00:00:00'), 4.0, "{'temp': '2.6°C', 'pressure': '892.6 hPa', 'vibrations': '0.6207148776200955 m/s²'}", 0, 0.6207148776200955, ' m/s²', 892.6, ' hPa', 2.6, '°C']
# ['V05478176', 'A321_1458', Timestamp('2024-07-23 00:00:00'), 4.0, "{'temp': '2.6°C', 'pressure': '892.6 hPa', 'vibrations': '0.6207148776200955 m/s²'}", 0, 2.6, '°C', 892.6, ' hPa', 0.6207148776200955, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08901777', 'A330_4129', Timestamp('2024-07-23 00:00:00'), 5.6, "{'temp': '7.2°C', 'pressure': '1008.1 hPa', 'vibrations': '4.7007368908028395 m/s²'}", 0, 4.7007368908028395, ' m/s²', 1008.1, ' hPa', 7.2, '°C']
# ['V08901777', 'A330_4129', Timestamp('2024-07-23 00:00:00'), 5.6, "{'temp': '7.2°C', 'pressure': '1008.1 hPa', 'vibrations': '4.7007368908028395 m/s²'}", 0, 7.2, '°C', 1008.1, ' hPa', 4.7007368908028395, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06509965', 'CRJ700_4386', Timestamp('2024-07-23 00:00:00'), 11.1, "{'temp': '6.3°C', 'pressure': '974.4 hPa', 'vibrations': '3.2865464702227163 m/s²'}", 1, 3.2865464702227163, ' m/s²', 974.4, ' hPa', 6.3, '°C']
# ['V06509965', 'CRJ700_4386', Timestamp('2024-07-23 00:00:00'), 11.1, "{'temp': '6.3°C', 'pressure': '974.4 hPa', 'vibrations': '3.2865464702227163 m/s²'}", 1, 6.3, '°C', 974.4, ' hPa', 3.2865464702227163, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02782770', 'B777_3776', Timestamp('2024-07-23 00:00:00'), 7.4, "{'temp': '-3.4°C', 'pressure': '926.3 hPa', 'vibrations': '1.9067713975612377 m/s²'}", 0, 1.9067713975612377, ' m/s²', 926.3, ' hPa', -3.4, '°C']
# ['V02782770', 'B777_3776', Timestamp('2024-07-23 00:00:00'), 7.4, "{'temp': '-3.4°C', 'pressure': '926.3 hPa', 'vibrations': '1.9067713975612377 m/s²'}", 0, -3.4, '°C', 926.3, ' hPa', 1.9067713975612377, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01151067', 'B747_4725', Timestamp('2024-07-23 00:00:00'), 5.7, "{'temp': '10.5°C', 'pressure': '940.0 hPa', 'vibrations': '4.3884800811912825 m/s²'}", 0, 4.3884800811912825, ' m/s²', 940.0, ' hPa', 10.5, '°C']
# ['V01151067', 'B747_4725', Timestamp('2024-07-23 00:00:00'), 5.7, "{'temp': '10.5°C', 'pressure': '940.0 hPa', 'vibrations': '4.3884800811912825 m/s²'}", 0, 10.5, '°C', 940.0, ' hPa', 4.3884800811912825, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05590486', 'A350_5987', Timestamp('2024-07-23 00:00:00'), 3.5, "{'temp': '1.5°C', 'pressure': '1071.5 hPa', 'vibrations': '2.008421927069915 m/s²'}", 0, 2.008421927069915, ' m/s²', 1071.5, ' hPa', 1.5, '°C']
# ['V05590486', 'A350_5987', Timestamp('2024-07-23 00:00:00'), 3.5, "{'temp': '1.5°C', 'pressure': '1071.5 hPa', 'vibrations': '2.008421927069915 m/s²'}", 0, 1.5, '°C', 1071.5, ' hPa', 2.008421927069915, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04483806', 'A350_1177', Timestamp('2024-07-23 00:00:00'), 8.1, "{'temp': '-6.9°C', 'pressure': '876.1 hPa', 'vibrations': '4.043252794652731 m/s²'}", 2, 4.043252794652731, ' m/s²', 876.1, ' hPa', -6.9, '°C']
# ['V04483806', 'A350_1177', Timestamp('2024-07-23 00:00:00'), 8.1, "{'temp': '-6.9°C', 'pressure': '876.1 hPa', 'vibrations': '4.043252794652731 m/s²'}", 2, -6.9, '°C', 876.1, ' hPa', 4.043252794652731, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01941903', 'B777_6867', Timestamp('2024-07-23 00:00:00'), 1.1, "{'temp': '-2.3°C', 'pressure': '898.3 hPa', 'vibrations': '4.752821711175696 m/s²'}", 0, 4.752821711175696, ' m/s²', 898.3, ' hPa', -2.3, '°C']
# ['V01941903', 'B777_6867', Timestamp('2024-07-23 00:00:00'), 1.1, "{'temp': '-2.3°C', 'pressure': '898.3 hPa', 'vibrations': '4.752821711175696 m/s²'}", 0, -2.3, '°C', 898.3, ' hPa', 4.752821711175696, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02544136', 'A380_4294', Timestamp('2024-07-23 00:00:00'), 3.1, "{'temp': '-16.3°C', 'pressure': '974.0 hPa', 'vibrations': '1.8283595211329051 m/s²'}", 1, 1.8283595211329051, ' m/s²', 974.0, ' hPa', -16.3, '°C']
# ['V02544136', 'A380_4294', Timestamp('2024-07-23 00:00:00'), 3.1, "{'temp': '-16.3°C', 'pressure': '974.0 hPa', 'vibrations': '1.8283595211329051 m/s²'}", 1, -16.3, '°C', 974.0, ' hPa', 1.8283595211329051, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V00623924', 'A330_4856', Timestamp('2024-07-23 00:00:00'), 3.4, "{'temp': '10.2°C', 'pressure': '960.3 hPa', 'vibrations': '0.3783351356100967 m/s²'}", 0, 0.3783351356100967, ' m/s²', 960.3, ' hPa', 10.2, '°C']
# ['V00623924', 'A330_4856', Timestamp('2024-07-23 00:00:00'), 3.4, "{'temp': '10.2°C', 'pressure': '960.3 hPa', 'vibrations': '0.3783351356100967 m/s²'}", 0, 10.2, '°C', 960.3, ' hPa', 0.3783351356100967, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02772950', 'B777_5812', Timestamp('2024-07-23 00:00:00'), 7.3, "{'temp': '-12.6°C', 'pressure': '958.7 hPa', 'vibrations': '1.253955813168719 m/s²'}", 2, 1.253955813168719, ' m/s²', 958.7, ' hPa', -12.6, '°C']
# ['V02772950', 'B777_5812', Timestamp('2024-07-23 00:00:00'), 7.3, "{'temp': '-12.6°C', 'pressure': '958.7 hPa', 'vibrations': '1.253955813168719 m/s²'}", 2, -12.6, '°C', 958.7, ' hPa', 1.253955813168719, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03635783', 'CRJ700_3108', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '-14.3°C', 'pressure': '997.0 hPa', 'vibrations': '4.560995689452482 m/s²'}", 1, 4.560995689452482, ' m/s²', 997.0, ' hPa', -14.3, '°C']
# ['V03635783', 'CRJ700_3108', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '-14.3°C', 'pressure': '997.0 hPa', 'vibrations': '4.560995689452482 m/s²'}", 1, -14.3, '°C', 997.0, ' hPa', 4.560995689452482, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02131541', 'A350_4039', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '1.2°C', 'pressure': '948.0 hPa', 'vibrations': '4.404778721477408 m/s²'}", 2, 4.404778721477408, ' m/s²', 948.0, ' hPa', 1.2, '°C']
# ['V02131541', 'A350_4039', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '1.2°C', 'pressure': '948.0 hPa', 'vibrations': '4.404778721477408 m/s²'}", 2, 1.2, '°C', 948.0, ' hPa', 4.404778721477408, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V01386393', 'A340_3962', Timestamp('2024-07-23 00:00:00'), 9.2, "{'temp': '4.9°C', 'pressure': '895.6 hPa', 'vibrations': '3.240715656925666 m/s²'}", 0, 3.240715656925666, ' m/s²', 895.6, ' hPa', 4.9, '°C']
# ['V01386393', 'A340_3962', Timestamp('2024-07-23 00:00:00'), 9.2, "{'temp': '4.9°C', 'pressure': '895.6 hPa', 'vibrations': '3.240715656925666 m/s²'}", 0, 4.9, '°C', 895.6, ' hPa', 3.240715656925666, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09556159', 'A321_1968', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '0.7°C', 'pressure': '911.5 hPa', 'vibrations': '3.5991836893084406 m/s²'}", 0, 3.5991836893084406, ' m/s²', 911.5, ' hPa', 0.7, '°C']
# ['V09556159', 'A321_1968', Timestamp('2024-07-23 00:00:00'), 1.5, "{'temp': '0.7°C', 'pressure': '911.5 hPa', 'vibrations': '3.5991836893084406 m/s²'}", 0, 0.7, '°C', 911.5, ' hPa', 3.5991836893084406, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08450538', 'B747_6297', Timestamp('2024-07-23 00:00:00'), 4.1, "{'temp': '11.4°C', 'pressure': '869.6 hPa', 'vibrations': '0.9075653094863162 m/s²'}", 0, 0.9075653094863162, ' m/s²', 869.6, ' hPa', 11.4, '°C']
# ['V08450538', 'B747_6297', Timestamp('2024-07-23 00:00:00'), 4.1, "{'temp': '11.4°C', 'pressure': '869.6 hPa', 'vibrations': '0.9075653094863162 m/s²'}", 0, 11.4, '°C', 869.6, ' hPa', 0.9075653094863162, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09776060', 'B767_3878', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '-2.3°C', 'pressure': '971.0 hPa', 'vibrations': '3.2824077021503957 m/s²'}", 0, 3.2824077021503957, ' m/s²', 971.0, ' hPa', -2.3, '°C']
# ['V09776060', 'B767_3878', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '-2.3°C', 'pressure': '971.0 hPa', 'vibrations': '3.2824077021503957 m/s²'}", 0, -2.3, '°C', 971.0, ' hPa', 3.2824077021503957, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03836110', 'A330_4046', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '6.1°C', 'pressure': '975.5 hPa', 'vibrations': '0.5593603873731923 m/s²'}", 0, 0.5593603873731923, ' m/s²', 975.5, ' hPa', 6.1, '°C']
# ['V03836110', 'A330_4046', Timestamp('2024-07-23 00:00:00'), 2.6, "{'temp': '6.1°C', 'pressure': '975.5 hPa', 'vibrations': '0.5593603873731923 m/s²'}", 0, 6.1, '°C', 975.5, ' hPa', 0.5593603873731923, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02818794', 'B747_4007', Timestamp('2024-07-23 00:00:00'), 2.1, "{'temp': '6.6°C', 'pressure': '878.7 hPa', 'vibrations': '3.8428125653271734 m/s²'}", 0, 3.8428125653271734, ' m/s²', 878.7, ' hPa', 6.6, '°C']
# ['V02818794', 'B747_4007', Timestamp('2024-07-23 00:00:00'), 2.1, "{'temp': '6.6°C', 'pressure': '878.7 hPa', 'vibrations': '3.8428125653271734 m/s²'}", 0, 6.6, '°C', 878.7, ' hPa', 3.8428125653271734, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08596203', 'B757_4595', Timestamp('2024-07-23 00:00:00'), 3.6, "{'temp': '-13.1°C', 'pressure': '984.6 hPa', 'vibrations': '1.312429482444345 m/s²'}", 1, 1.312429482444345, ' m/s²', 984.6, ' hPa', -13.1, '°C']
# ['V08596203', 'B757_4595', Timestamp('2024-07-23 00:00:00'), 3.6, "{'temp': '-13.1°C', 'pressure': '984.6 hPa', 'vibrations': '1.312429482444345 m/s²'}", 1, -13.1, '°C', 984.6, ' hPa', 1.312429482444345, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07020913', 'E170_4215', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '8.9°C', 'pressure': '934.7 hPa', 'vibrations': '1.4642732012977056 m/s²'}", 0, 1.4642732012977056, ' m/s²', 934.7, ' hPa', 8.9, '°C']
# ['V07020913', 'E170_4215', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '8.9°C', 'pressure': '934.7 hPa', 'vibrations': '1.4642732012977056 m/s²'}", 0, 8.9, '°C', 934.7, ' hPa', 1.4642732012977056, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06031954', 'B737_1117', Timestamp('2024-07-23 00:00:00'), 5.5, "{'temp': '6.5°C', 'pressure': '874.2 hPa', 'vibrations': '0.8771713451337604 m/s²'}", 0, 0.8771713451337604, ' m/s²', 874.2, ' hPa', 6.5, '°C']
# ['V06031954', 'B737_1117', Timestamp('2024-07-23 00:00:00'), 5.5, "{'temp': '6.5°C', 'pressure': '874.2 hPa', 'vibrations': '0.8771713451337604 m/s²'}", 0, 6.5, '°C', 874.2, ' hPa', 0.8771713451337604, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06630632', 'B767_5501', Timestamp('2024-07-23 00:00:00'), 5.2, "{'temp': '12.3°C', 'pressure': '947.0 hPa', 'vibrations': '4.007212090077841 m/s²'}", 0, 4.007212090077841, ' m/s²', 947.0, ' hPa', 12.3, '°C']
# ['V06630632', 'B767_5501', Timestamp('2024-07-23 00:00:00'), 5.2, "{'temp': '12.3°C', 'pressure': '947.0 hPa', 'vibrations': '4.007212090077841 m/s²'}", 0, 12.3, '°C', 947.0, ' hPa', 4.007212090077841, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05224562', 'B737_0616', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '6.0°C', 'pressure': '987.5 hPa', 'vibrations': '0.9453712016976479 m/s²'}", 0, 0.9453712016976479, ' m/s²', 987.5, ' hPa', 6.0, '°C']
# ['V05224562', 'B737_0616', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '6.0°C', 'pressure': '987.5 hPa', 'vibrations': '0.9453712016976479 m/s²'}", 0, 6.0, '°C', 987.5, ' hPa', 0.9453712016976479, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09482781', 'CRJ900_4042', Timestamp('2024-07-23 00:00:00'), 4.6, "{'temp': '-1.8°C', 'pressure': '1011.3 hPa', 'vibrations': '4.481656303536174 m/s²'}", 0, 4.481656303536174, ' m/s²', 1011.3, ' hPa', -1.8, '°C']
# ['V09482781', 'CRJ900_4042', Timestamp('2024-07-23 00:00:00'), 4.6, "{'temp': '-1.8°C', 'pressure': '1011.3 hPa', 'vibrations': '4.481656303536174 m/s²'}", 0, -1.8, '°C', 1011.3, ' hPa', 4.481656303536174, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07981483', 'B777_4962', Timestamp('2024-07-23 00:00:00'), 7.2, "{'temp': '4.7°C', 'pressure': '909.8 hPa', 'vibrations': '3.5369554823871314 m/s²'}", 0, 3.5369554823871314, ' m/s²', 909.8, ' hPa', 4.7, '°C']
# ['V07981483', 'B777_4962', Timestamp('2024-07-23 00:00:00'), 7.2, "{'temp': '4.7°C', 'pressure': '909.8 hPa', 'vibrations': '3.5369554823871314 m/s²'}", 0, 4.7, '°C', 909.8, ' hPa', 3.5369554823871314, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02938059', 'B747_0262', Timestamp('2024-07-23 00:00:00'), 4.0, "{'temp': '12.7°C', 'pressure': '960.0 hPa', 'vibrations': '4.090086166953922 m/s²'}", 0, 4.090086166953922, ' m/s²', 960.0, ' hPa', 12.7, '°C']
# ['V02938059', 'B747_0262', Timestamp('2024-07-23 00:00:00'), 4.0, "{'temp': '12.7°C', 'pressure': '960.0 hPa', 'vibrations': '4.090086166953922 m/s²'}", 0, 12.7, '°C', 960.0, ' hPa', 4.090086166953922, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04579702', 'A380_6878', Timestamp('2024-07-23 00:00:00'), 8.4, "{'temp': '3.4°C', 'pressure': '941.4 hPa', 'vibrations': '0.9000699366440335 m/s²'}", 0, 0.9000699366440335, ' m/s²', 941.4, ' hPa', 3.4, '°C']
# ['V04579702', 'A380_6878', Timestamp('2024-07-23 00:00:00'), 8.4, "{'temp': '3.4°C', 'pressure': '941.4 hPa', 'vibrations': '0.9000699366440335 m/s²'}", 0, 3.4, '°C', 941.4, ' hPa', 0.9000699366440335, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V04042885', 'B777_5963', Timestamp('2024-07-23 00:00:00'), 5.0, "{'temp': '6.9°C', 'pressure': '946.9 hPa', 'vibrations': '2.924278008126955 m/s²'}", 0, 2.924278008126955, ' m/s²', 946.9, ' hPa', 6.9, '°C']
# ['V04042885', 'B777_5963', Timestamp('2024-07-23 00:00:00'), 5.0, "{'temp': '6.9°C', 'pressure': '946.9 hPa', 'vibrations': '2.924278008126955 m/s²'}", 0, 6.9, '°C', 946.9, ' hPa', 2.924278008126955, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05386200', 'E170_6420', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '-1.2°C', 'pressure': '980.7 hPa', 'vibrations': '2.028528094550927 m/s²'}", 0, 2.028528094550927, ' m/s²', 980.7, ' hPa', -1.2, '°C']
# ['V05386200', 'E170_6420', Timestamp('2024-07-23 00:00:00'), 0.6, "{'temp': '-1.2°C', 'pressure': '980.7 hPa', 'vibrations': '2.028528094550927 m/s²'}", 0, -1.2, '°C', 980.7, ' hPa', 2.028528094550927, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07002979', 'E170_6723', Timestamp('2024-07-23 00:00:00'), 3.7, "{'temp': '-16.5°C', 'pressure': '998.9 hPa', 'vibrations': '1.0543362493925716 m/s²'}", 1, 1.0543362493925716, ' m/s²', 998.9, ' hPa', -16.5, '°C']
# ['V07002979', 'E170_6723', Timestamp('2024-07-23 00:00:00'), 3.7, "{'temp': '-16.5°C', 'pressure': '998.9 hPa', 'vibrations': '1.0543362493925716 m/s²'}", 1, -16.5, '°C', 998.9, ' hPa', 1.0543362493925716, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V03749155', 'A320_6731', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '-6.1°C', 'pressure': '967.0 hPa', 'vibrations': '2.605473767973235 m/s²'}", 0, 2.605473767973235, ' m/s²', 967.0, ' hPa', -6.1, '°C']
# ['V03749155', 'A320_6731', Timestamp('2024-07-23 00:00:00'), 4.8, "{'temp': '-6.1°C', 'pressure': '967.0 hPa', 'vibrations': '2.605473767973235 m/s²'}", 0, -6.1, '°C', 967.0, ' hPa', 2.605473767973235, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08000810', 'A380_3155', Timestamp('2024-07-23 00:00:00'), 6.9, "{'temp': '-13.5°C', 'pressure': '990.5 hPa', 'vibrations': '2.5823624665946716 m/s²'}", 1, 2.5823624665946716, ' m/s²', 990.5, ' hPa', -13.5, '°C']
# ['V08000810', 'A380_3155', Timestamp('2024-07-23 00:00:00'), 6.9, "{'temp': '-13.5°C', 'pressure': '990.5 hPa', 'vibrations': '2.5823624665946716 m/s²'}", 1, -13.5, '°C', 990.5, ' hPa', 2.5823624665946716, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V06695461', 'B777_4029', Timestamp('2024-07-23 00:00:00'), 5.8, "{'temp': '-2.1°C', 'pressure': '916.8 hPa', 'vibrations': '3.744115104679027 m/s²'}", 0, 3.744115104679027, ' m/s²', 916.8, ' hPa', -2.1, '°C']
# ['V06695461', 'B777_4029', Timestamp('2024-07-23 00:00:00'), 5.8, "{'temp': '-2.1°C', 'pressure': '916.8 hPa', 'vibrations': '3.744115104679027 m/s²'}", 0, -2.1, '°C', 916.8, ' hPa', 3.744115104679027, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V08697719', 'A320_6242', Timestamp('2024-07-23 00:00:00'), 6.3, "{'temp': '-9.1°C', 'pressure': '915.2 hPa', 'vibrations': '1.7425687278464812 m/s²'}", 0, 1.7425687278464812, ' m/s²', 915.2, ' hPa', -9.1, '°C']
# ['V08697719', 'A320_6242', Timestamp('2024-07-23 00:00:00'), 6.3, "{'temp': '-9.1°C', 'pressure': '915.2 hPa', 'vibrations': '1.7425687278464812 m/s²'}", 0, -9.1, '°C', 915.2, ' hPa', 1.7425687278464812, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V02658480', 'A321_6807', Timestamp('2024-07-23 00:00:00'), 3.3, "{'temp': '-1.2°C', 'pressure': '990.5 hPa', 'vibrations': '0.08019859165691368 m/s²'}", 0, 0.08019859165691368, ' m/s²', 990.5, ' hPa', -1.2, '°C']
# ['V02658480', 'A321_6807', Timestamp('2024-07-23 00:00:00'), 3.3, "{'temp': '-1.2°C', 'pressure': '990.5 hPa', 'vibrations': '0.08019859165691368 m/s²'}", 0, -1.2, '°C', 990.5, ' hPa', 0.08019859165691368, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V07485675', 'A380_2079', Timestamp('2024-07-23 00:00:00'), 6.0, "{'temp': '-1.8°C', 'pressure': '1058.5 hPa', 'vibrations': '3.7879311710617065 m/s²'}", 0, 3.7879311710617065, ' m/s²', 1058.5, ' hPa', -1.8, '°C']
# ['V07485675', 'A380_2079', Timestamp('2024-07-23 00:00:00'), 6.0, "{'temp': '-1.8°C', 'pressure': '1058.5 hPa', 'vibrations': '3.7879311710617065 m/s²'}", 0, -1.8, '°C', 1058.5, ' hPa', 3.7879311710617065, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09152696', 'A320_3521', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '3.3°C', 'pressure': '927.9 hPa', 'vibrations': '0.7135096790417039 m/s²'}", 0, 0.7135096790417039, ' m/s²', 927.9, ' hPa', 3.3, '°C']
# ['V09152696', 'A320_3521', Timestamp('2024-07-23 00:00:00'), 3.8, "{'temp': '3.3°C', 'pressure': '927.9 hPa', 'vibrations': '0.7135096790417039 m/s²'}", 0, 3.3, '°C', 927.9, ' hPa', 0.7135096790417039, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V09947994', 'A330_6979', Timestamp('2024-07-23 00:00:00'), 7.5, "{'temp': '15.1°C', 'pressure': '1027.0 hPa', 'vibrations': '0.20036076612601983 m/s²'}", 0, 0.20036076612601983, ' m/s²', 1027.0, ' hPa', 15.1, '°C']
# ['V09947994', 'A330_6979', Timestamp('2024-07-23 00:00:00'), 7.5, "{'temp': '15.1°C', 'pressure': '1027.0 hPa', 'vibrations': '0.20036076612601983 m/s²'}", 0, 15.1, '°C', 1027.0, ' hPa', 0.20036076612601983, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05970470', 'E175_4558', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '4.4°C', 'pressure': '885.5 hPa', 'vibrations': '2.4732161905961245 m/s²'}", 0, 2.4732161905961245, ' m/s²', 885.5, ' hPa', 4.4, '°C']
# ['V05970470', 'E175_4558', Timestamp('2024-07-23 00:00:00'), 4.5, "{'temp': '4.4°C', 'pressure': '885.5 hPa', 'vibrations': '2.4732161905961245 m/s²'}", 0, 4.4, '°C', 885.5, ' hPa', 2.4732161905961245, ' m/s²']
#
# Comparaison des données pour MàJ :
# ['V05359338', 'A380_3162', Timestamp('2024-07-23 00:00:00'), 6.4, "{'temp': '-4.3°C', 'pressure': '1093.4 hPa', 'vibrations': '3.887488899545162 m/s²'}", 0, 3.887488899545162, ' m/s²', 1093.4, ' hPa', -4.3, '°C']
# ['V05359338', 'A380_3162', Timestamp('2024-07-23 00:00:00'), 6.4, "{'temp': '-4.3°C', 'pressure': '1093.4 hPa', 'vibrations': '3.887488899545162 m/s²'}", 0, -4.3, '°C', 1093.4, ' hPa', 3.887488899545162, ' m/s²']
#
# Nombre de lignes insérées : 0
# Nombre de lignes mises à jour : 93
